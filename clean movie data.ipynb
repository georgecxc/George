# %%
import pandas

# %%
df=pandas.read_csv('MoviesOnStreamingPlatform.csv')
df
# Out:
#           ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010  13+   8.8             87%
# 1          2                      The Matrix  1999  18+   8.7             87%
# 2          3          Avengers: Infinity War  2018  13+   8.5             84%
# 3          4              Back to the Future  1985   7+   8.5             96%
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
# ...      ...                             ...   ...  ...   ...             ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2             NaN
# 16740  16741                  The Poof Point  2001   7+   4.7             NaN
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7             NaN
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6             NaN
# 16743  16744                In Beaver Valley  1950  NaN   NaN             NaN
#
# ...

# %%
df=df.drop(['Title','ID','Directors'],axis=1)

# %%
df
# Out:
#        Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0      2010  13+   8.8             87%        1     0            0        0
# 1      1999  18+   8.7             87%        1     0            0        0
# 2      2018  13+   8.5             84%        1     0            0        0
# 3      1985   7+   8.5             96%        1     0            0        0
# 4      1966  18+   8.8             97%        1     0            1        0
# ...     ...  ...   ...             ...      ...   ...          ...      ...
# 16739  1980  NaN   6.2             NaN        0     0            0        1
# 16740  2001   7+   4.7             NaN        0     0            0        1
# 16741  2013  NaN   5.7             NaN        0     0            0        1
# 16742  2017  NaN   6.6             NaN        0     0            0        1
# 16743  1950  NaN   NaN             NaN        0     0            0        1
#
# ...

# %%
df.isnull().sum()
# Out:
# Year                      0
# Age                    8844
# IMDb                    333
# Rotten Tomatoes       10954
# Netflix                   0
# Hulu                      0
# Prime Video               0
# Disney+                   0
# Genres                    0
# Country                   0
# Language                  0
# Runtime                 243
# Rotten Tomatoes(%)    10954
# dtype: int64

# %%
df=df.dropna(axis=0,subset=['Genres','Country','Language'])

# %%
def per(x):
    if not pandas.isna(x):
        x=x[:-1]
        return float(x)

# %%
df['Rotten Tomatoes(%)']=df['Rotten Tomatoes'].apply(per)
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\2801820217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rotten Tomatoes(%)']=df['Rotten Tomatoes'].apply(per)

# %%
df
# Out:
#        Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0      2010  13+   8.8             87%        1     0            0        0
# 1      1999  18+   8.7             87%        1     0            0        0
# 2      2018  13+   8.5             84%        1     0            0        0
# 3      1985   7+   8.5             96%        1     0            0        0
# 4      1966  18+   8.8             97%        1     0            1        0
# ...     ...  ...   ...             ...      ...   ...          ...      ...
# 16739  1980  NaN   6.2             NaN        0     0            0        1
# 16740  2001   7+   4.7             NaN        0     0            0        1
# 16741  2013  NaN   5.7             NaN        0     0            0        1
# 16742  2017  NaN   6.6             NaN        0     0            0        1
# 16743  1950  NaN   NaN             NaN        0     0            0        1
#
# ...

# %%
df['Genres']=df['Genres'].str.split(',')
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\2144546164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genres']=df['Genres'].str.split(',')

# %%
df['Country']=df['Country'].str.split(',')
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\3580391605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country']=df['Country'].str.split(',')

# %%
df['Language']=df['Language'].str.split(',')
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\3691020346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language']=df['Language'].str.split(',')

# %%
df
# Out:
#        Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0      2010  13+   8.8             87%        1     0            0        0
# 1      1999  18+   8.7             87%        1     0            0        0
# 2      2018  13+   8.5             84%        1     0            0        0
# 3      1985   7+   8.5             96%        1     0            0        0
# 4      1966  18+   8.8             97%        1     0            1        0
# ...     ...  ...   ...             ...      ...   ...          ...      ...
# 16739  1980  NaN   6.2             NaN        0     0            0        1
# 16740  2001   7+   4.7             NaN        0     0            0        1
# 16741  2013  NaN   5.7             NaN        0     0            0        1
# 16742  2017  NaN   6.6             NaN        0     0            0        1
# 16743  1950  NaN   NaN             NaN        0     0            0        1
#
# ...

# %%
def cou(x):
    if 'United States' in x:
        return 1
    else:
        return 0

# %%
df['isInUS']=df['Country'].apply(cou)
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\1935929826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isInUS']=df['Country'].apply(cou)

# %%
def lan(x):
    if 'English' in x:
        return 1
    else:
        return 0

# %%
df['isInEng']=df['Language'].apply(lan)
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\1725432466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isInEng']=df['Language'].apply(lan)

# %%
def mul(x):
    if len(x)>=2:
        return 1
    else:
        return 0

# %%
df['isMultiCountry']=df['Country'].apply(mul)
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\3418403496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isMultiCountry']=df['Country'].apply(mul)

# %%
df['isMultiLanguage']=df['Language'].apply(mul)
# Out:
# C:\Users\chexi\AppData\Local\Temp\ipykernel_23988\3835732598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isMultiLanguage']=df['Language'].apply(mul)

# %%
df1=df.explode('Genres')

# %%
df2=df.explode('Country')

# %%
df3=df.explode('Language')

# %%
df.to_csv('movieData.csv',index=False)

# %%
df1.to_csv('movieDataGenres.csv',index=False)

# %%
df2.to_csv('movieDataCountry.csv',index=False)

# %%
df3.to_csv('movieDataLanguage.csv',index=False)

# %%
df
# Out:
#        Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 0      2010  13+   8.8             87%        1     0            0        0
# 1      1999  18+   8.7             87%        1     0            0        0
# 2      2018  13+   8.5             84%        1     0            0        0
# 3      1985   7+   8.5             96%        1     0            0        0
# 4      1966  18+   8.8             97%        1     0            1        0
# ...     ...  ...   ...             ...      ...   ...          ...      ...
# 16739  1980  NaN   6.2             NaN        0     0            0        1
# 16740  2001   7+   4.7             NaN        0     0            0        1
# 16741  2013  NaN   5.7             NaN        0     0            0        1
# 16742  2017  NaN   6.6             NaN        0     0            0        1
# 16743  1950  NaN   NaN             NaN        0     0            0        1
#
# ...
